# %% [markdown]
# # Primer on NLP

# %%
# %matplotlib notebook
import re
import math
import string
from collections import Counter

# %%
TEXT = open('big.txt').read()

# %%
print(len(TEXT))
# Out:
# 581864

# %%
def tokens(text):
    """List all the word tokens (consecutive letters) in a text. Normalize to lowercase"""
    return re.findall('[a-z]+',text.lower())

# %%
WORDS = tokens(TEXT)

# %%
print(WORDS[:10])
# Out:
# ['project', 'gutenberg', 's', 'the', 'adventures', 'of', 'sherlock', 'holmes', 'by', 'arthur']

# %%
def sample(bag,n=10):
    """Samples 10 words randomly from bag"""
    return ' '.join(random.choice(bag) for _ in range(n))

# %%
sample(WORDS)
# Out:
# 'view her place met turn you young it trepoff that'

# %%
COUNTS = Counter(WORDS)
print(COUNTS.most_common(10))
# Out:
# [('the', 5810), ('and', 3088), ('i', 3038), ('to', 2823), ('of', 2778), ('a', 2701), ('in', 1823), ('that', 1767), ('it', 1749), ('you', 1572)]

# %%
for w in tokens('the rare and neverbeforeseen words'):
    print(COUNTS[w],w)
# Out:
# 5810 the
# 3 rare
# 3088 and
# 0 neverbeforeseen
# 46 words

# %%
M = COUNTS['the']

# %%
print(M)
# Out:
# 5810

# %%
M = COUNTS['the']
yscale('log');xscale('log'); title('Frequency of the n-th most frequent word and 1/n line.')
plot([c for (w,c) in COUNTS.most_common()])
plot([M/i for i in range(1,len(COUNTS)+1)])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Resume:
# http://nbviewer.jupyter.org/url/norvig.com/ipython/How%20to%20Do%20Things%20with%20Words.ipynb
# Section: (3) Task: spelling correction
